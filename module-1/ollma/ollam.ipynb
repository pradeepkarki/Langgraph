# %%
from typing import TypedDict
from pprint import pprint

from langgraph.graph import StateGraph
from langchain_community.chat_models import ChatOllama
from IPython.display import Image, display, JSON

# Use local Ollama model
llm = ChatOllama(model="qwen3:0.6b")     

# Define state
class State(TypedDict):
    input: str
    output: str

# %%
# Node function
def chatbot(state):
    response = llm.invoke(state["input"])
    pprint(response)

    display(JSON(response.model_dump(), expanded=True))
    #display response in json
    response_json = response
    print("LLM response (JSON):", response_json)
    
    state["output"] = response
    print("User input:", state["input"])
    print("LLM response:", state["output"])
    print("Chatbot response:", response)
    return {"output": response.content}

# Build graphs
graph = StateGraph(State)

graph.add_node("chatbot", chatbot)
graph.set_entry_point("chatbot")
graph.set_finish_point("chatbot")

app = graph.compile()

# Run
result = app.invoke({"input": "Explain python in simple terms."})
print(result["output"])
# Out:
# AIMessage(content='Python is a simple, powerful programming language that\'s easy to learn. Here\'s a simple explanation:\n\n1. **Simple and Easy to Learn**: Python is like a fun game, where you can make things like websites, apps, or even puzzles with just a few lines of code. It\'s not as complicated as languages like Java or C++.\n\n2. **Dynamic Data Types**: Unlike static languages, Python allows variables to change their type. For example, if you assign a number to a string, it becomes a string, and if you assign a string back, it\'s a number again.\n\n3. **Object-Oriented**: Think of Python as building blocks—variables and functions are like objects. You can create a "car" and a "carpet" and build programs using these objects.\n\n4. **Versatile**: Python is used in many areas: web development, data analysis, AI, and even everyday tasks like making a simple calculator.\n\n5. **Community and Resources**: Python has a huge user base, so there\'s a lot of help and resources available for learning.\n\nIn short, Python is like a language with lots of fun and applications—perfect for beginners! 🎉', additional_kwargs={}, response_metadata={'model': 'qwen3:0.6b', 'created_at': '2026-05-01T05:08:28.518831Z', 'message': {'role': 'assistant', 'content': ''}, 'done': True, 'done_reason': 'stop', 'total_duration': 10482061917, 'load_duration': 192176208, 'prompt_eval_count': 378, 'prompt_eval_duration': 583875708, 'eval_count': 243, 'eval_duration': 3563990204}, id='lc_run--019de1f0-09c4-7313-b135-2fdc9f736346-0', tool_calls=[], invalid_tool_calls=[])
# LLM response (JSON): content='Python is a simple, powerful programming language that\'s easy to learn. Here\'s a simple explanation:\n\n1. **Simple and Easy to Learn**: Python is like a fun game, where you can make things like websites, apps, or even puzzles with just a few lines of code. It\'s not as complicated as languages like Java or C++.\n\n2. **Dynamic Data Types**: Unlike static languages, Python allows variables to change their type. For example, if you assign a number to a string, it becomes a string, and if you assign a string back, it\'s a number again.\n\n3. **Object-Oriented**: Think of Python as building blocks—variables and functions are like objects. You can create a "car" and a "carpet" and build programs using these objects.\n\n4. **Versatile**: Python is used in many areas: web development, data analysis, AI, and even everyday tasks like making a simple calculator.\n\n5. **Community and Resources**: Python has a huge user base, so there\'s a lot of help and resources available for learning.\n\nIn short, Python is like a language with lots of fun and applications—perfect for beginners! 🎉' additional_kwargs={} response_metadata={'model': 'qwen3:0.6b', 'created_at': '2026-05-01T05:08:28.518831Z', 'message': {'role': 'assistant', 'content': ''}, 'done': True, 'done_reason': 'stop', 'total_duration': 10482061917, 'load_duration': 192176208, 'prompt_eval_count': 378, 'prompt_eval_duration': 583875708, 'eval_count': 243, 'eval_duration': 3563990204} id='lc_run--019de1f0-09c4-7313-b135-2fdc9f736346-0' tool_calls=[] invalid_tool_calls=[]
# User input: Explain python in simple terms.
# LLM response: content='Python is a simple, powerful programming language that\'s easy to learn. Here\'s a simple explanation:\n\n1. **Simple and Easy to Learn**: Python is like a fun game, where you can make things like websites, apps, or even puzzles with just a few lines of code. It\'s not as complicated as languages like Java or C++.\n\n2. **Dynamic Data Types**: Unlike static languages, Python allows variables to change their type. For example, if you assign a number to a string, it becomes a string, and if you assign a string back, it\'s a number again.\n\n3. **Object-Oriented**: Think of Python as building blocks—variables and functions are like objects. You can create a "car" and a "carpet" and build programs using these objects.\n\n4. **Versatile**: Python is used in many areas: web development, data analysis, AI, and even everyday tasks like making a simple calculator.\n\n5. **Community and Resources**: Python has a huge user base, so there\'s a lot of help and resources available for learning.\n\nIn short, Python is like a language with lots of fun and applications—perfect for beginners! 🎉' additional_kwargs={} response_metadata={'model': 'qwen3:0.6b', 'created_at': '2026-05-01T05:08:28.518831Z', 'message': {'role': 'assistant', 'content': ''}, 'done': True, 'done_reason': 'stop', 'total_duration': 10482061917, 'load_duration': 192176208, 'prompt_eval_count': 378, 'prompt_eval_duration': 583875708, 'eval_count': 243, 'eval_duration': 3563990204} id='lc_run--019de1f0-09c4-7313-b135-2fdc9f736346-0' tool_calls=[] invalid_tool_calls=[]
# Chatbot response: content='Python is a simple, powerful programming language that\'s easy to learn. Here\'s a simple explanation:\n\n1. **Simple and Easy to Learn**: Python is like a fun game, where you can make things like websites, apps, or even puzzles with just a few lines of code. It\'s not as complicated as languages like Java or C++.\n\n2. **Dynamic Data Types**: Unlike static languages, Python allows variables to change their type. For example, if you assign a number to a string, it becomes a string, and if you assign a string back, it\'s a number again.\n\n3. **Object-Oriented**: Think of Python as building blocks—variables and functions are like objects. You can create a "car" and a "carpet" and build programs using these objects.\n\n4. **Versatile**: Python is used in many areas: web development, data analysis, AI, and even everyday tasks like making a simple calculator.\n\n5. **Community and Resources**: Python has a huge user base, so there\'s a lot of help and resources available for learning.\n\nIn short, Python is like a language with lots of fun and applications—perfect for beginners! 🎉' additional_kwargs={} response_metadata={'model': 'qwen3:0.6b', 'created_at': '2026-05-01T05:08:28.518831Z', 'message': {'role': 'assistant', 'content': ''}, 'done': True, 'done_reason': 'stop', 'total_duration': 10482061917, 'load_duration': 192176208, 'prompt_eval_count': 378, 'prompt_eval_duration': 583875708, 'eval_count': 243, 'eval_duration': 3563990204} id='lc_run--019de1f0-09c4-7313-b135-2fdc9f736346-0' tool_calls=[] invalid_tool_calls=[]
# Python is a simple, powerful programming language that's easy to learn. Here's a simple explanation:
#
# 1. **Simple and Easy to Learn**: Python is like a fun game, where you can make things like websites, apps, or even puzzles with just a few lines of code. It's not as complicated as languages like Java or C++.
#
# 2. **Dynamic Data Types**: Unlike static languages, Python allows variables to change their type. For example, if you assign a number to a string, it becomes a string, and if you assign a string back, it's a number again.
#
# 3. **Object-Oriented**: Think of Python as building blocks—variables and functions are like objects. You can create a "car" and a "carpet" and build programs using these objects.
#
# 4. **Versatile**: Python is used in many areas: web development, data analysis, AI, and even everyday tasks like making a simple calculator.
#
# 5. **Community and Resources**: Python has a huge user base, so there's a lot of help and resources available for learning.
#
# In short, Python is like a language with lots of fun and applications—perfect for beginners! 🎉

# %%
# Show
display(Image(app.get_graph(xray=True).draw_mermaid_png()))
